# %% [raw]
# ---
# title: "Miembros"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ## Activos
#
# ::: {layout-ncol=2}
#
# ::: {#col-felipe}
# ![](Imagenes/JFHLY.png){fig-align="center" width="80%"}
#
# **Dr. Juan Felipe Huan Lew Yee**
# *Profesor*
# :::
#
# ::: {#col-lizeth}
# ![](Imagenes/LFN.png){fig-align="center" width="80%"}
#
# **M. en C. Lizeth Franco Nolasco**
# *Estudiante de Doctorado*
# :::
#
# ::: {#col-alonso}
# ![](Imagenes/AVR.png){fig-align="center" width="80%"}
#
# **Alonso Vargas Ríos**
# *Estudiante de Licenciatura*
# :::
#
# :::

# %% [raw]
# ---
# title: "Miembros"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [raw]
# ## Activos

# %% [markdown]
# ::: {.grid}
#
# ::: {.g-col-12 .g-col-md-4}
# ![](Imagenes/JFHLY.png){width="100%" .rounded}
#
# **Dr. Juan Felipe Huan Lew Yee**
# *Profesor*
# [{{< fa envelope >}}](mailto:felipe.lew.yee@quimica.unam.mx) [{{< fa brands github >}}](https://github.com/felipelewyee) [{{< fa brands google-scholar >}}](https://scholar.google.com.mx/citations?user=-rfbPGEAAAAJ&hl) [{{< fa brands orcid >}}](https://orcid.org/my-orcid?orcid=0000-0002-3908-3144)
# :::
#
# ::: {.g-col-12 .g-col-md-4}
# ![](Imagenes/LFN.png){width="100%" .rounded}
#
# **M. en C. Lizeth Franco Nolasco**
# *Estudiante de Doctorado*
# [{{< fa brands github >}}](https://github.com/francolizeth) [{{< fa brands google-scholar >}}](https://scholar.google.com.mx/citations?user=ilY3ZwIAAAAJ&hl) [{{< fa brands orcid >}}](https://orcid.org/0000-0003-3841-6231)
# :::
#
# ::: {.g-col-12 .g-col-md-4}
# ![](Imagenes/AVR.png){width="100%" .rounded}
#
# **Alonso Vargas Ríos**
# *Estudiante de Licenciatura*
# :::
#
# :::

# %% [raw]
# ---
# title: "Software"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# ::: {layout-ncol=2}
#
# ::: {#col-DoNOF}
# **DoNOF**
#
# [![](Imagenes/DoNOF.png){fig-align="center" width="80%"}](https://github.com/DoNOF/DoNOFsw)
# ![](Imagenes/Fortran.png){fig-align="center" width="20%"}
# :::
#
# ::: {#col-PyNOF}
# **PyNOF**
#
# [![](Imagenes/PyNOF.png){fig-align="center" width="80%"}](https://github.com/DoNOF/PyNOF)
# ![](Imagenes/Python.png){fig-align="center" width="20%"}
# :::
#
# ::: {#col-DoNOF.jl}
# **DoNOF.jl**
#
# [![](Imagenes/DoNOFjl.png){fig-align="center" width="80%"}](https://github.com/DoNOF/DoNOF.jl)
# ![](Imagenes/Julia.png){fig-align="center" width="20%"}
# :::
#
# :::

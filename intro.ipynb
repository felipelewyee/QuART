# %% [raw]
# ---
# title: Sea bienvenido a este lugar!
# page-layout: full
# jupyter: python3
# ---

# %% [markdown]
# Esta es la página del grupo de investigación del **Dr. Juan Felipe Huan Lew Yee**, ubicado en la Facultad de Química (**FQ**) de la Universidad Nacional Autónoma de México (**UNAM**).
#
# ![](Imagenes/UNAM.png){width="10%"} ![](Imagenes/FQ.jpeg){width="10%"}

# %% [markdown]
# ::: {.column-screen .bg-light .padding-hero style="background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%); padding: 60px 20px; text-align: center; margin-bottom: 40px;"}
#
# # ![](Imagenes/QuART.png){width="30%"}
#
# **Qu**antum **A**lgorithms and **R**DM **T**heory **Lab**oratory
#
# **Qu**antum **ART**ificial **Lab**oratory
#
# En el **QuART Lab**, nos ubicamos en la frontera del conocimiento combinando la **Teoría de Matrices de Densidad Reducida (1-RDM)**, el **Aprendizaje Automático** y la **Computación Cuántica** para modelar y predecir fenómenos químicos complejos tanto en arquitecturas clásicas como cuánticas.
#
# [Ver nuestro Software](./software.html){.btn .btn-primary .btn-lg role="button"}  [Conoce al Equipo](./miembros.html){.btn .btn-outline-secondary .btn-lg role="button"}
# :::

# %% [markdown]
# ## Estancia de Investigación 2026-II
#
# Foto del grupo armando una computadora en su primer día (Junio, 2026).
#
# ![](Imagenes/Estancia-2026-II.jpg){width="70%"}

# %% [raw]
# ## Líneas de Investigación
#
# ::: {.grid}
#
# ::: {.g-col-12 .g-col-md-4 .card .p-3}
# ### {{< fa atom >}} Química Cuántica & NOFT
# Desarrollamos e implementamos métodos avanzados basados en la Teoría del Funcional de Orbitales Naturales (NOFT). Buscamos capturar la correlación estática y dinámica simultáneamente con un costo computacional polinómico eficiente.
# :::
#
# ::: {.g-col-12 .g-col-md-4 .card .p-3}
# ### {{< fa brain >}} Inteligencia Artificial
# Integramos algoritmos de *Machine Learning* y arquitecturas de aprendizaje profundo para predecir propiedades moleculares, corregir matrices de densidad reducida y acelerar significativamente la convergencia y diseño de nuevos funcionales.
# :::
#
# ::: {.g-col-12 .g-col-md-4 .card .p-3}
# ### {{< fa microchip >}} Computación Cuántica
# Exploramos nuevos algoritmos y metodologías para química cuántica en cómputo cuántico.
# :::
#
# :::

# %% [markdown]
# ::: {.callout-note appearance="simple" icon=false}
# ## ¿Te interesa unirte al grupo?
# Siempre estamos buscando estudiantes motivados de Licenciatura, Maestría o Doctorado en Química que deseen especializarse en química teórica y computacional. Escríbenos en la sección de [Contacto](./contacto.html).
# :::
